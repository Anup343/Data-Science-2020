# %% [markdown]
# # Dallas police incident data set

# %% [markdown]
# Using Request Library to get data from API key

# %%
#import requests

# %%
#r=requests.get('https://www.dallasopendata.com/resource/qv6i-rri7.json')

# %%
#r.status_code

# %% [markdown]
# Converting jason file to dictionary

# %%
#r_dict=r.json()

# %%
#r.json()

# %%
#type(r)

# %%
#print(r_dict)

# %%
#type(r_dict)

# %%
#df=pd.DataFrame(r_dict)

# %%
#df.head()
#df.tail()
#df.shape
#df.columns

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# creating dataframe from CSV file

# %%
df1=pd.read_csv(r"C:\Users\anupb\Downloads\Police_Incidents.csv", low_memory= False)

# %%
display(df1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-a9b7aafd475e> in <module>
# ----> 1 display(df1)
#
# ~\anaconda3\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630610 entries, 0 to 630609
# Data columns (total 100 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   Incident Number w/year                     630610 non-null  object
#  1   Year of Incident                           630610 non-null  int64
#  2   Service Number ID                          630610 non-null  object
#  3   Watch                                      630610 non-null  int64
#  4   Call (911) Problem                         611791 non-null  object
#  5   Type of Incident                           630610 non-null  object
#  6   Type  Location                             629828 non-null  object
#  7   Type of Property                           143258 non-null  object
#  8   Incident Address                           628722 non-null  object
# ...

# %%
df1.corr()
# Out:
#                                            Year of Incident     Watch  \
# Year of Incident                                   1.000000  0.080947
# Watch                                              0.080947  1.000000
# Reporting Area                                    -0.001464  0.013949
# Beat                                              -0.006255  0.008507
# Sector                                            -0.006263  0.008390
# Year1 of Occurrence                                0.987013  0.086139
# Day1 of the Year                                  -0.127692 -0.005481
# Year2 of Occurrence                                0.996621  0.081764
# Day2 of the Year                                  -0.129389 -0.005450
# Offense Entered Year                               0.999912  0.080956
# Offense Entered  Date/Time                        -0.131528 -0.004668
# Victim Age                                         0.004767 -0.026841
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(df1.corr())

# %%
df1.head()
# Out:
#   Incident Number w/year  Year of Incident Service Number ID  Watch  \
# 0            153402-2019              2019    153402-2019-01      1
# 1            800201-2020              2020    800201-2020-01      3
# 2            803146-2020              2020    803146-2020-01      2
# 3            801951-2019              2019    801951-2019-01      3
# 4            144779-2018              2018    144779-2018-01      2
#
#                Call (911) Problem  \
# 0  41/11B - BURG BUSN IN PROGRESS
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                      09V - UUMV
#
#                                               Type of Incident  \
# 0                          BURGLARY OF BUILDING - FORCED ENTRY
# 1  CREDIT CARD OR DEBIT CARD ABUSE - PRELIMINARY INVESTIGATION
# 2  CREDIT CARD OR DEBIT CARD ABUSE - PRELIMINARY INVESTIGATION
# 3                                   LOST PROPERTY (NO OFFENSE)
# ...

# %%
df1.shape
# Out:
# (630610, 100)

# %% [markdown]
# Checking for missing value False=no missing, True=missing

# %%
df1.isna().any()

# %%
df1.isna().any().tolist()

# %% [markdown]
# print total column with missing value

# %%
print(len(df1.columns[df1.isna().any()]))

# %% [markdown]
# print total column with non missing value

# %%
print(len(df1.columns[df1.notna().all()]))

# %% [markdown]
# To check total missing values for each column

# %%
df1.isnull().sum()

# %%
df1.isna().sum()

# %%
count_nan = len(df1) - df1.count()
count_nan

# %%
df1.describe()

# %%
df1.dtypes
